# %%
import pandas
import matplotlib.pyplot as plt

# %%
df1= pandas.read_csv("data.csv")

# %%
df1
# Out:
#      member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0      1296599     5000.0       5000.0      4975.000000   36 months     10.65
# 1      1314167     2500.0       2500.0      2500.000000   60 months     15.27
# 2      1313524     2400.0       2400.0      2400.000000   36 months     15.96
# 3      1277178    10000.0      10000.0     10000.000000   36 months     13.49
# 4      1311748     3000.0       3000.0      3000.000000   60 months     12.69
# 5      1311441     5000.0       5000.0      5000.000000   36 months      7.90
# 6      1304742     7000.0       7000.0      7000.000000   60 months     15.96
# 7      1288686     3000.0       3000.0      3000.000000   36 months     18.64
# 8      1306957     5600.0       5600.0      5600.000000   60 months     21.28
# 9      1306721     5375.0       5375.0      5350.000000   60 months     12.69
# 10     1305201     6500.0       6500.0      6500.000000   60 months     14.65
# ...

# %%
df1 = df1[["purpose", "int_rate"]]
df1
# Out:
#                 purpose  int_rate
# 0           credit_card     10.65
# 1                   car     15.27
# 2        small_business     15.96
# 3                 other     13.49
# 4                 other     12.69
# 5               wedding      7.90
# 6    debt_consolidation     15.96
# 7                   car     18.64
# 8        small_business     21.28
# 9                 other     12.69
# 10   debt_consolidation     14.65
# 11   debt_consolidation     12.69
# 12   debt_consolidation     13.49
# 13          credit_card      9.91
# 14                other     10.65
# 15   debt_consolidation     16.29
# 16     home_improvement     15.27
# 17       major_purchase      6.03
# 18              medical     11.71
# 19   debt_consolidation      6.03
# 20   debt_consolidation     15.27
# 21   debt_consolidation     12.42
# 22          credit_card     11.71
# 23   debt_consolidation     11.71
# 24       major_purchase     11.71
# 25          credit_card      9.91
# ...

# %%
df1 = df1.groupby("purpose").mean()

# %%
df1
# Out:
#                      int_rate
# purpose
# car                 13.638571
# credit_card         12.142889
# debt_consolidation  12.864312
# home_improvement    15.346000
# house               17.270000
# major_purchase      10.941667
# medical             10.636667
# moving               9.910000
# other               13.268182
# small_business      13.323000
# vacation            12.420000
# wedding              7.900000

# %%
df1.columns=["Avg_Int_rate"]

# %% [markdown]
# df1

# %%
df1
# Out:
#                     Avg_Int_rate
# purpose
# car                    13.638571
# credit_card            12.142889
# debt_consolidation     12.864312
# home_improvement       15.346000
# house                  17.270000
# major_purchase         10.941667
# medical                10.636667
# moving                  9.910000
# other                  13.268182
# small_business         13.323000
# vacation               12.420000
# wedding                 7.900000

# %%
df1.plot.bar(y="Avg_Int_rate",rot=90)
plt.xlabel("Purpose")
plt.ylabel("Average Interest Rate")
plt.tight_layout()
plt.show()
